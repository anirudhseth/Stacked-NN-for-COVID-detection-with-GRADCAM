# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from data_module import *

# %% [markdown]
# ### read data with col names

# %%
col_names=['id', 'location', 'type', 'extra'] 
df = pd.read_csv("E:/deepLearning/data/test_split_v3.txt",sep=" ",names = col_names)

# %% [markdown]
# ### a sample of a row of dataset

# %%
df.iloc[1]
# Out:
# id                                                         31
# location    streptococcus-pneumoniae-pneumonia-temporal-ev...
# type                                                pneumonia
# extra                                                      PA
# Name: 1, dtype: object

# %% [markdown]
# ### open and show a file

# %%
img = cv2.imread("E:/deepLearning/data/test/" + df.location[0])

# %%
img.shape
# Out:
# (1593, 1800, 3)

# %%
plt.imshow(img)

# %% [markdown]
# # Data loader test

# %%
generator = BalanceCovidDataset(data_dir="E:/deepLearning/data",
                                csv_file="train_split_v3.txt",
                                covid_percent=0.1,
                                batch_size=8,
                                augmentation=False,
                                class_weights=[1., 1., 12]) #weights for normal, pneumonia, covid19
# Out:
# #normal+pneumonia:  14891  #covid19:  236

# %%
img_batch, label, weight = next(generator)

# %%
img_batch.shape, img_batch[0].shape, label.size
# Out:
# ((8, 224, 224, 3), (224, 224, 3), 24)

# %%
plt.imshow(img_batch[0])

# %%
plt.imshow(img_batch[7])
